# %%
import pandas as pd

# --- Paths ---
flow_path = r"D:\Development\RESEARCH\Gazelle_Valley\Data\discharge\flow_events_processed.csv"
rain_path = r"D:\Development\RESEARCH\Gazelle_Valley\Data\Precipiteion_Data\Ram\20231004_20250406.csv"

# --- Parameters ---
rain_buffer_hours = 48
intensity_window_minutes = 10

# --- Load flow events ---
flow_events = pd.read_csv(flow_path)
flow_events['event_start'] = pd.to_datetime(flow_events['flow_start_date'] + ' ' + flow_events['flow_start_time'])
flow_events['event_end'] = pd.to_datetime(flow_events['flow_end_date'] + ' ' + flow_events['flow_end_time'])

# --- Load rain data ---
rain_data = pd.read_csv(rain_path)
rain_data['timestamp'] = pd.to_datetime(rain_data['Date Time'], dayfirst=True, errors='coerce')
rain_data.rename(columns={'Rain (mm)': 'rain_mm'}, inplace=True)
rain_data.dropna(subset=['timestamp', 'rain_mm'], inplace=True)
rain_data.sort_values('timestamp', inplace=True)
rain_data.reset_index(drop=True, inplace=True)

# --- Check if time intervals are constant ---
time_diffs = rain_data['timestamp'].diff().dropna().dt.total_seconds()
unique_diffs = time_diffs.unique()

if len(unique_diffs) == 1:
    time_step_seconds = unique_diffs[0]
    print(f"🕒 Detected constant time step: {time_step_seconds} seconds")
else:
    raise ValueError(f"❌ Time intervals are not uniform! Unique intervals found (s): {unique_diffs}")

# --- Compute rolling window size ---
window_size = int((intensity_window_minutes * 60) / time_step_seconds)

# --- Process rainfall per event ---
rain_event_rows = []

for _, event in flow_events.iterrows():
    start = event['event_start'] - pd.Timedelta(hours=rain_buffer_hours)
    end = event['event_end'] + pd.Timedelta(hours=rain_buffer_hours)

    event_rain = rain_data[(rain_data['timestamp'] >= start) & (rain_data['timestamp'] <= end)].copy()
    total_rain = event_rain['rain_mm'].sum()

    if len(event_rain) >= window_size:
        rolling_sum = event_rain['rain_mm'].rolling(window=window_size).sum()
        max_intensity = (rolling_sum / (intensity_window_minutes / 60)).max()
        max_idx = rolling_sum.idxmax()
        max_time = rain_data.loc[max_idx, 'timestamp']
    else:
        max_intensity = 0
        max_time = pd.NaT

    rain_event_rows.append({
        'rain_start_date': start.date(),
        'rain_start_time': start.time(),
        'rain_end_date': end.date(),
        'rain_end_time': end.time(),
        'rain_givat_ram_total_mm': total_rain,
        'rain_givat_ram_max_intensity_mm_hr': max_intensity,
        'rain_givat_ram_max_intensity_date': max_time.date() if pd.notna(max_time) else None,
        'rain_givat_ram_max_intensity_time': max_time.time() if pd.notna(max_time) else None
    })

# --- Create DataFrame and save ---
rain_summary = pd.DataFrame(rain_event_rows)

output_path = r"D:\Development\RESEARCH\Gazelle_Valley\Data\discharge\rain_events_summary_givat_ram.csv"
rain_summary.to_csv(output_path, index=False)

print("✅ Rain event summary saved to:")
print(output_path)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21004\2680357330.py in <module>
#      30     print(f"🕒 Detected constant time step: {time_step_seconds} seconds")
#      31 else:
# ---> 32     raise ValueError(f"❌ Time intervals are not uniform! Unique intervals found (s): {unique_diffs}")
#      33
#      34 # --- Compute rolling window size ---
#
# ValueError: ❌ Time intervals are not uniform! Unique intervals found (s): [ 600. 1200. 2400. 1800.]

# %%
# חישוב הפרשים בין טיימסטמפים
rain_data['time_diff_sec'] = rain_data['timestamp'].diff().dt.total_seconds()

# מציאת אינטרוול הנפוץ (הנכון)
expected_interval = rain_data['time_diff_sec'].mode().iloc[0]

# סינון שורות בהן האינטרוול לא שווה לאינטרוול הצפוי
bad_intervals = rain_data[rain_data['time_diff_sec'] != expected_interval]

# תצוגה
print(f"🔍 Found {len(bad_intervals)} rows with unexpected intervals (≠ {expected_interval} sec)")
bad_intervals
# Out:
# 🔍 Found 10 rows with unexpected intervals (≠ 600.0 sec)
#               Date Time  rain_mm           timestamp  time_diff_sec
# 0       04/10/2023 0:00      0.0 2023-10-04 00:00:00            NaN
# 2953   24/10/2023 12:20      0.0 2023-10-24 12:20:00         1200.0
# 10996   19/12/2023 9:00      0.0 2023-12-19 09:00:00         1200.0
# 25987  01/04/2024 11:40      0.0 2024-04-01 11:40:00         1200.0
# 37202   18/06/2024 9:00      0.0 2024-06-18 09:00:00         1200.0
# 48610  05/09/2024 14:50      0.0 2024-09-05 14:50:00         2400.0
# 48612  05/09/2024 15:20      0.0 2024-09-05 15:20:00         1200.0
# 48696   06/09/2024 5:40      0.0 2024-09-06 05:40:00         1800.0
# 50038  15/09/2024 13:40      0.0 2024-09-15 13:40:00         1800.0
# 55066  20/10/2024 11:50      0.0 2024-10-20 11:50:00         1200.0

# %%
# --- Load flow and rain data ---
flow_path = r"D:\Development\RESEARCH\Gazelle_Valley\Data\discharge\flow_events_processed.csv"
rain_path = r"D:\Development\RESEARCH\Gazelle_Valley\Data\discharge\rain_events_summary_givat_ram.csv"

flow_events = pd.read_csv(flow_path)
rain_summary = pd.read_csv(rain_path)

# --- Parse timestamps ---
flow_events['event_start'] = pd.to_datetime(flow_events['flow_start_date'] + ' ' + flow_events['flow_start_time'])
flow_events['event_end'] = pd.to_datetime(flow_events['flow_end_date'] + ' ' + flow_events['flow_end_time'])

# --- Assign rainy season and event_id ---
def get_rainy_season(date):
    return date.year + 1 if date.month >= 9 else date.year

flow_events['rainy_season'] = flow_events['event_start'].apply(get_rainy_season)
season_map = {season: i+1 for i, season in enumerate(sorted(flow_events['rainy_season'].unique()))}
flow_events['season_index'] = flow_events['rainy_season'].map(season_map)
flow_events['event_id'] = flow_events.groupby('rainy_season').cumcount() + 1
flow_events['event_id'] = flow_events['season_index'] * 100 + flow_events['event_id']

# Drop season helpers
flow_events.drop(columns=['rainy_season', 'season_index'], inplace=True)

# --- Merge datasets ---
flow_events.reset_index(drop=True, inplace=True)
rain_summary.reset_index(drop=True, inplace=True)
combined = pd.concat([flow_events, rain_summary], axis=1)

# --- Set MultiIndex columns (only for the data columns, not event_id) ---
event_id = combined['event_id']
combined.drop(columns='event_id', inplace=True)

discharge_cols = flow_events.columns.drop(['event_id'])
rain_cols = rain_summary.columns

multi_index_cols = (
    [('discharge_data', col) for col in discharge_cols] +
    [('givat_ram_rain_gauge', col) for col in rain_cols]
)

combined.columns = pd.MultiIndex.from_tuples(multi_index_cols)
combined.index = event_id
combined.index.name = 'event_id'

# --- Save to CSV ---
output_path = r"D:\Development\RESEARCH\Gazelle_Valley\Data\discharge\flow_and_rain_events_combined_multiindex.csv"
combined.to_csv(output_path)

print("✅ MultiIndex DataFrame saved properly with index = event_id")
print(output_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21260\1289918196.py in <module>
#       4
#       5 flow_events = pd.read_csv(flow_path)
# ----> 6 rain_summary = pd.read_csv(rain_path)
#       7
#       8 # --- Parse timestamps ---
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# ~\Anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
combined
# Out:
#           discharge_data                                              \
#          flow_start_date flow_start_time flow_end_date flow_end_time
# event_id
# 101           2023-11-01        12:20:00    2023-11-03      11:00:00
# 102           2023-11-14        16:30:00    2023-11-14      17:05:00
# 103           2023-11-19        14:20:00    2023-11-21      16:15:00
# 104           2023-11-27        04:05:00    2023-11-27      18:10:00
# 105           2023-12-05        16:20:00    2023-12-06      12:40:00
# 106           2023-12-13        04:35:00    2023-12-13      15:30:00
# 107           2023-12-22        05:55:00    2023-12-24      16:55:00
# 108           2024-01-02        02:40:00    2024-01-02      21:20:00
# 109           2024-01-10        23:50:00    2024-01-15      11:40:00
# 110           2024-01-18        15:35:00    2024-01-18      16:45:00
# 111           2024-01-23        13:20:00    2024-01-30      11:05:00
# ...

# %% [markdown]
# שתי בעיות שצריך לפתור:
# 1. להעיף אירועים לא רלוונטים, להגדיר מהו אירוע לא רלוונט, כנראה שזה יהיה אירוע שבו אין גשם בתחנה.
# 2. לפי מה אני מחלץ את הזמנים של התחלת וסוף האירוע. לדעתי זה צריך להופיע רק פעם אחת והפעם אחת הזו צריכה להיגזר בהתאם לגשם.
# שים לב שתאריכי ההתחלה והסוף של הספיקה הם בדיוק כשנגמרת ומתחילה הספיקה, אז אולי צריך ללכת לזמנים האלה ולחפש את הגשם שקדם לזמן ההתחלה ואת  הגשם שאחרי זמן הסיום (אם קיים כזה, אם לא - לתת שם מרווח של זמן מסויים בכל זאת).
#
# בשורה התחתונה - האירוע יתחיל עם תנאי מסויים ביחס לכמות גשם מסויימת שירדה בטווח זמן מסויים לפני תחילת אירוע הספיקה ויגמר עם או בצורת חישוב דומה לאחרי הזמן
# האחרון של הספיקה או לפי זמן מסויים שאגדיר (בהיעדר גשם אחרי הספיקה)
#
# 3. הקוד חייב להיות יפה יותר עם שמות אינטואיטיבים יותר כולל שם הקובת שנשמר בסוף.
# 4. הידרוגרף לא יזיק. ההידרוגרף יקח את תאריכי ההתחלה והסיום וייגש לקבצים הגולמיים של הנתונים ויקח משם את הנתונים

# %%
# --- Import libraries ---
import pandas as pd
import matplotlib.pyplot as plt


flow_events_path = r"D:\Development\RESEARCH\Gazelle_Valley\Data\discharge\flow_events_processed.csv"
rain_path = r"D:\Development\RESEARCH\Gazelle_Valley\Data\Precipiteion_Data\Ram\20231004_20250406.csv"

# --- Load flow events ---
flow_events = pd.read_csv(flow_events_path)

# Create full datetime objects for start and end
flow_events['event_start'] = pd.to_datetime(flow_events['flow_start_date'] + ' ' + flow_events['flow_start_time'])
flow_events['event_end'] = pd.to_datetime(flow_events['flow_end_date'] + ' ' + flow_events['flow_end_time'])

# %%
flow_events
# Out:
#    flow_start_date flow_start_time flow_end_date flow_end_time  \
# 0       2023-11-01        12:20:00    2023-11-03      11:00:00
# 1       2023-11-14        16:30:00    2023-11-14      17:05:00
# 2       2023-11-19        14:20:00    2023-11-21      16:15:00
# 3       2023-11-27        04:05:00    2023-11-27      18:10:00
# 4       2023-12-05        16:20:00    2023-12-06      12:40:00
# 5       2023-12-13        04:35:00    2023-12-13      15:30:00
# 6       2023-12-22        05:55:00    2023-12-24      16:55:00
# 7       2024-01-02        02:40:00    2024-01-02      21:20:00
# 8       2024-01-10        23:50:00    2024-01-15      11:40:00
# 9       2024-01-18        15:35:00    2024-01-18      16:45:00
# 10      2024-01-23        13:20:00    2024-01-30      11:05:00
# 11      2024-02-02        00:25:00    2024-02-06      01:25:00
# 12      2024-02-13        09:30:00    2024-02-14      05:20:00
# 13      2024-02-18        11:00:00    2024-02-22      20:15:00
# ...

# %%
import pandas as pd

# --- Load flow events table ---
flow_path = r"D:\Development\RESEARCH\Gazelle_Valley\Data\discharge\flow_events_processed.csv"
flow_events = pd.read_csv(flow_path)

# Parse full timestamps for start and end
flow_events['event_start'] = pd.to_datetime(flow_events['flow_start_date'] + ' ' + flow_events['flow_start_time'])
flow_events['event_end'] = pd.to_datetime(flow_events['flow_end_date'] + ' ' + flow_events['flow_end_time'])

# --- Load rainfall summary table ---
rain_path = r"D:\Development\RESEARCH\Gazelle_Valley\Data\discharge\rain_events_summary_givat_ram.csv"
rain_summary = pd.read_csv(rain_path)

# --- Assign rainy season ID (Sep–Sep) ---
def get_rainy_season(date):
    return date.year + 1 if date.month >= 9 else date.year

flow_events['rainy_season'] = flow_events['event_start'].apply(get_rainy_season)

# --- Generate event_id: 101, 102, ..., 201, 202, etc. ---
season_numbers = {season: i + 1 for i, season in enumerate(sorted(flow_events['rainy_season'].unique()))}
flow_events['season_index'] = flow_events['rainy_season'].map(season_numbers)
flow_events['event_number_in_season'] = flow_events.groupby('rainy_season').cumcount() + 1
flow_events['event_id'] = flow_events['season_index'] * 100 + flow_events['event_number_in_season']

# --- Merge both tables by index (assumes 1:1 order match) ---
flow_events.reset_index(drop=True, inplace=True)
rain_summary.reset_index(drop=True, inplace=True)
combined_df = pd.concat([flow_events, rain_summary], axis=1)

# --- Reorder columns to show event_id first ---
cols = ['event_id'] + [col for col in combined_df.columns if col != 'event_id']
combined_df = combined_df[cols]

# --- Export merged table to CSV ---
output_path = r"D:\Development\RESEARCH\Gazelle_Valley\Data\discharge\flow_and_rain_events_combined.csv"
combined_df.to_csv(output_path, index=False)
combined_df
# Out:
#     event_id flow_start_date flow_start_time flow_end_date flow_end_time  \
# 0        101      2023-11-01        12:20:00    2023-11-03      11:00:00
# 1        102      2023-11-14        16:30:00    2023-11-14      17:05:00
# 2        103      2023-11-19        14:20:00    2023-11-21      16:15:00
# 3        104      2023-11-27        04:05:00    2023-11-27      18:10:00
# 4        105      2023-12-05        16:20:00    2023-12-06      12:40:00
# 5        106      2023-12-13        04:35:00    2023-12-13      15:30:00
# 6        107      2023-12-22        05:55:00    2023-12-24      16:55:00
# 7        108      2024-01-02        02:40:00    2024-01-02      21:20:00
# 8        109      2024-01-10        23:50:00    2024-01-15      11:40:00
# 9        110      2024-01-18        15:35:00    2024-01-18      16:45:00
# 10       111      2024-01-23        13:20:00    2024-01-30      11:05:00
# 11       112      2024-02-02        00:25:00    2024-02-06      01:25:00
# ...

# %%
combined_df.columns
# Out:
# Index(['event_id', 'flow_start_date', 'flow_start_time', 'flow_end_date',
#        'flow_end_time', 'flow_total_volume_m3', 'flow_peak_date',
#        'flow_peak_time', 'flow_peak_m3_s', 'event_start', 'event_end',
#        'rainy_season', 'season_index', 'event_number_in_season',
#        'rain_start_date', 'rain_start_time', 'rain_end_date', 'rain_end_time',
#        'rain_givat_ram_total_mm', 'rain_givat_ram_max_intensity_mm_hr',
#        'rain_givat_ram_max_intensity_date',
#        'rain_givat_ram_max_intensity_time'],
#       dtype='object')

# %%
len(combined_df)
# Out:
# 35

# %%
plt.figure(figsize=(6, 6))
plt.scatter(flow_events['total_rain_mm'], flow_events['flow_total_volume_m3'], alpha=0.7)

plt.xlabel("Total Rainfall (mm)")
plt.ylabel("Peak Discharge (m³/s)")
plt.title("Peak Discharge vs. Total Rainfall")
plt.grid(True)
plt.tight_layout()
plt.show()
